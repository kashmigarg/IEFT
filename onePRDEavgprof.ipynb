# %%
import csv
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


def avg_profit(i,j):
    data = pd.read_csv('1PRDEK' + str(i) + 'F' + str(j) + '_ZIC201_avg_balance.csv', header=None)
    profit = []
    time = []
    row = 1300000
    while row < 1307488:
#         if (data.iloc[row, 1]) ==7600000:
        c = len(data.columns)-2
        profit.append(data.iloc[row, c])
        time.append(data.iloc[row, 1])
#         print(profit)
        row+=1
#     print(profit)

#     profit = data.iloc[len(data)-2, len(data.columns)-2]
#     print(len(data)-2)
#     print(len(data.columns)-2)
#     print(profit)
    return time, profit

def compute_profit(k_values,f_values):
#     profit_values = []
    i=0
#     j=0
    while i < len(k_values):
        t, p = avg_profit(k_values[i],f_values)
#         while j < 1:
#             y = avg_profit(k_values[i],f_values)
#             profit_values.insert(i, y)
#             j+=1
        i += 1
    return t,p


def plot_avg_p():
    k_values = [4]
    f_values = [0.5]
    f_value = [0.8]
    f_valu = [1.5]
    i=0
    color = ['blue', 'red', 'green']
    
    t, p = compute_profit(k_values,f_values[i])
    t1, p1 = compute_profit(k_values,f_value[i])
    t2, p2 = compute_profit(k_values,f_valu[i])
    
    fig, ax = plt.subplots()
    ax.plot(t, p, 'r-', label='avg p per t')
    ax.plot(t1, p1, 'b-', label='avg p per t')
    ax.plot(t2, p2, 'g-', label='avg p per t')
    plt.show()
    
#     while i < len(f_values):
#         profit_values = compute_profit(k_values,f_values[i])
        
#         fig, ax = plt.subplots()
#         plt.bar(k_values,profit_values, width=0.5, alpha=0.5, color=color[i], label="average")
#         ax.plot(t, p, 'b-', label='avg p per t')
#         plt.show()
#         i+=1
        
plot_avg_p()

def plot_avg_f():
    k_values = [4,5,8,10]
    f_values = [0.5, 0.8, 1.5]
    i=0
    color = ['blue', 'red', 'green','yellow']
    while i < len(k_values):
        profit_values = compute_profit(k_values,f_values[i])
        fig, ax = plt.subplots()
        plt.bar(f_values,profit_values, width=0.1, alpha=0.5, color=color[i], label="average")
        plt.show()
        i+=1
        
# plot_avg_f()

        
#     profit_values = compute_profit(k_values,0.5)
#     fig, ax = plt.subplots()
#     plt.bar(k_values,profit_values, width=0.5, alpha=0.5, color='blue', label="average")
#     plt.show()
    
#     profit_values = compute_profit(k_values,0.8)
#     fig, ax = plt.subplots()
#     plt.bar(k_values,profit_values, width=0.5, alpha=0.5, color='red', label="average")
#     plt.show()
    
#     profit_values = compute_profit(k_values,1.5)
#     fig, ax = plt.subplots()
#     plt.bar(k_values,profit_values, width=0.5, alpha=0.5, color='green', label="average")
#     plt.show()

#     f_values = [1.5]
#     k_values = [4,5,8,10]
#     profit_values = []
#     i=0
#     j=0
#     while i < len(k_values):
#         while j < len(f_values):
#             y = avg_profit(k_values[i],f_values[j])
#             profit_values.insert(i, y)
#             j+=1
#         i = i+1

#     f_values = [0.8]
#     k_values = [4,5,8,10]
#     profit_values = []
#     i=0
#     j=0
#     while i < len(k_values):
#         while j < len(f_values):
#             y = avg_profit(k_values[i],f_values[j])
#             profit_values.insert(i, y)
#             j+=1
#         i = i+1
#     fig, ax = plt.subplots()
#     plt.bar(k_values,profit_values, width=0.5, alpha=0.5, color='red', label="average")
#     plt.show()
    
#     f_values = [0.5]
#     k_values = [4,5,8,10]
#     profit_values = []
#     i=0
#     j=0
#     while i < len(k_values):
#         while j < len(f_values):
#             y = avg_profit(k_values[i],f_values[j])
#             profit_values.insert(i, y)
#             j+=1
#         i = i+1
#     fig, ax = plt.subplots()
#     plt.bar(k_values,profit_values, width=0.5, alpha=0.5, color='green', label="average")
#     plt.show()
# Out:
# <ipython-input-2-66524b37c801>:68: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   plot_avg_p()
# <ipython-input-2-66524b37c801>:68: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   plot_avg_p()
